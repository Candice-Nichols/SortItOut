# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
#differences between pdb and em map
import seaborn as sns
sns.set(style="whitegrid")
import pandas as pd
diff_p = pd.read_csv("diff_plot2.csv")
sns.set_palette("Set3")
ax = sns.violinplot(x=diff_p["group"],y=diff_p["diff pdb em"],hue=diff_p["Linreg"],split=True,inner="quartile")

# %%
#differences between pdb and em map (new equation)
import seaborn as sns
sns.set(style="whitegrid")
import pandas as pd
diff_p = pd.read_csv("diff_plot3.csv")
sns.set_palette("Set3")
ax = sns.violinplot(x=diff_p["group"],y=diff_p["diff pdb em"],hue=diff_p["Linreg"],split=True,inner="quartile")

# %%
#pdb volume spread before and after linear regression
sns.set(style="whitegrid")
pdb_p = pd.read_csv("pdbvol_linreg2.csv")
sns.set_palette("Set3")
ax = sns.violinplot(x=pdb_p["GROUP"],y=pdb_p["PDBVOL"],hue=pdb_p["LINREG"],split=True,inner="quartile")

# %%
#pdb volume spread before and after linear regression (new equation)
sns.set(style="whitegrid")
pdb_p = pd.read_csv("pdbvol_linreg3.csv")
sns.set_palette("Set3")
ax = sns.violinplot(x=pdb_p["GROUP"],y=pdb_p["PDBVOL"],hue=pdb_p["LINREG"],split=True,inner="quartile")

# %%
#clustering group a
sensitivity=[0.230769231,0.384615385,0.230769231,0.538461538,0.769230769]
specificity=[0.852564103,0.782051282,0.782051282,0.666666667,0.557692308]
methods=['nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window']
clusters=['nn_2','nn_3','sw_1','sw_2','sw_3']

df= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity, 'specificity':specificity})
df
ax=sns.relplot(data=df,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

#clustering group a (new equation)
sensitivity2=[0.230769231,0.384615385,0.230769231,0.53846154,0.692307692]
specificity2=[0.852564103,0.782051282,0.782051282,0.666666667,0.551282051]
methods=['nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window']
clusters=['nn_2','nn_3','sw_1','sw_2','sw_3']

df2= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity2, 'specificity':specificity2})
df2
ax=sns.relplot(data=df2,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

# %%
#clustering group b
sensitivity=[0.3125,0.4375,0.6875,0.875,0.9375]
specificity=[0.8875,0.829166667,0.854166667,0.75,0.645833333]
methods=['nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window']
clusters=['nn_2','nn_3','sw_1','sw_2','sw_3']

df= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity, 'specificity':specificity})
df
ax=sns.relplot(data=df,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

#clustering group b (new equation)
sensitivity2=[0.3125,0.5,0.625,0.875,0.9375]
specificity2=[0.8875,0.833333333,0.85,0.75,0.645833333]
methods=['nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window']
clusters=['nn_2','nn_3','sw_1','sw_2','sw_3']

df2= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity2, 'specificity':specificity2})
df2
ax=sns.relplot(data=df2,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

# %%
#clustering group c
sensitivity=[0.75,1,1,1,1]
specificity=[0.821428571,0.714285714,0.75,0.535714286,0.357142857]
methods=['nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window']
clusters=['nn_3','nn_4','sw_1','sw_2','sw_3']

df= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity, 'specificity':specificity})
df
ax=sns.relplot(data=df,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

#clustering group c (new equation)
sensitivity2=[0.875,1,1,1,1]
specificity2=[0.839285714,0.714285714,0.75,0.535714286,0.357142857]
methods=['nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window']
clusters=['nn_3','nn_4','sw_1','sw_2','sw_3']

df2= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity2, 'specificity':specificity2})
df2
ax=sns.relplot(data=df2,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

# %%
#clustering group d
sensitivity=[0.4,0.8,0.6,1,1]
specificity=[0.6,0.45,0.5,0.3,0.1]
methods=['nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window']
clusters=['nn_2','nn_3','sw_1','sw_2','sw_3']

df= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity, 'specificity':specificity})
df
ax=sns.relplot(data=df,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

#clustering group d (new equations)
sensitivity2=[0.6,1,0.8,1,1]
specificity2=[0.7,0.5,0.55,0.3,0.1]
methods=['nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window']
clusters=['nn_2','nn_3','sw_1','sw_2','sw_3']

df2= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity2, 'specificity':specificity2})
df2
ax=sns.relplot(data=df2,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

# %%
#combine the above four graphs
sensitivity=[0.230769231,0.384615385,0.230769231,0.538461538,0.769230769,0.3125,0.4375,0.6875,0.875,0.9375,0.75,1,1,1,1,0.4,0.8,0.6,1,1]
specificity=[0.852564103,0.782051282,0.782051282,0.666666667,0.557692308,0.8875,0.829166667,0.854166667,0.75,0.645833333,0.821428571,0.714285714,0.75,0.535714286,0.357142857,0.6,0.45,0.5,0.3,0.1]
methods=['nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window','nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window','nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window','nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window']
clusters=['nn_2','nn_3','sw_1','sw_2','sw_3','nn_2','nn_3','sw_1','sw_2','sw_3','nn_2','nn_3','sw_1','sw_2','sw_3','nn_2','nn_3','sw_1','sw_2','sw_3']
group=['group a','group a','group a','group a','group a','group b','group b','group b','group b','group b','group c','group c','group c','group c','group c','group d','group d','group d','group d','group d']

df= pd.DataFrame({'methods':methods,'clusters':clusters, 'group':group , 'sensitivity':sensitivity, 'specificity':specificity})
df
ax=sns.relplot(data=df,s=100, x="sensitivity", y="specificity", hue= "group", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

#combine the above four graphs (new equation)
sensitivity2=[0.230769231,0.384615385,0.230769231,0.53846154,0.692307692,0.3125,0.5,0.625,0.875,0.9375,0.875,1,1,1,1,0.6,1,0.8,1,1]
specificity2=[0.852564103,0.782051282,0.782051282,0.666666667,0.551282051,0.8875,0.833333333,0.85,0.75,0.645833333,0.839285714,0.714285714,0.75,0.535714286,0.357142857,0.7,0.5,0.55,0.3,0.1]
methods=['nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window','nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window','nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window','nearest neighbor','nearest neighbor','sliding window','sliding window','sliding window']
clusters=['nn_2','nn_3','sw_1','sw_2','sw_3','nn_2','nn_3','sw_1','sw_2','sw_3','nn_2','nn_3','sw_1','sw_2','sw_3','nn_2','nn_3','sw_1','sw_2','sw_3']
group=['group a','group a','group a','group a','group a','group b','group b','group b','group b','group b','group c','group c','group c','group c','group c','group d','group d','group d','group d','group d']

df2= pd.DataFrame({'methods':methods,'clusters':clusters, 'group':group , 'sensitivity':sensitivity2, 'specificity':specificity2})
df2
ax=sns.relplot(data=df2,s=100, x="sensitivity", y="specificity", hue= "group", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

# %%
#clustering overall
sensitivity=[0.19047619,0.285714286,0.357142857,0.571428571,0.69047619]
specificity=[0.955865273,0.933797909,0.911149826,0.895470383,0.853077816]
methods=['nearest neighbor','nearest neighbor','nearest neighbor','sliding window','sliding window']
clusters=['nn_2','nn_3','nn_4','sw_2','sw_3']

df= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity, 'specificity':specificity})
df
ax=sns.relplot(data=df,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

#clustering overall (new equation)
sensitivity2=[0.238095238,0.357142857,0.452380952,0.57142857,0.642857143]
specificity2=[0.957026713,0.93554007,0.913472706,0.895470383,0.851916376]
methods=['nearest neighbor','nearest neighbor','nearest neighbor','sliding window','sliding window']
clusters=['nn_2','nn_3','nn_4','sw_2','sw_3']

df2= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity2, 'specificity':specificity2})
df2
ax=sns.relplot(data=df2,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

# %%
#clustering overall (removed missing densities)
sensitivity=[0.210526316,0.289473684,0.342105263,0.605263158,0.815789474]
specificity=[0.951635846,0.926742532,0.90113798,0.885490754,0.841394026]
methods=['nearest neighbor','nearest neighbor','nearest neighbor','sliding window','sliding window']
clusters=['nn_2','nn_3','nn_4','sw_2','sw_3']

df= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity, 'specificity':specificity})
df
ax=sns.relplot(data=df,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))

#clustering overall (removed missing densities) (new equation)
sensitivity2=[0.289473684,0.394736842,0.473684211,0.578947368,0.842105263]
specificity2=[0.953769559,0.929587482,0.904694168,0.884779516,0.842105263]
methods=['nearest neighbor','nearest neighbor','nearest neighbor','sliding window','sliding window']
clusters=['nn_2','nn_3','nn_4','sw_2','sw_3']

df2= pd.DataFrame({'methods':methods,'clusters':clusters, 'sensitivity':sensitivity2, 'specificity':specificity2})
df2
ax=sns.relplot(data=df2,s=100, x="sensitivity", y="specificity", hue= "methods", style="clusters")
sns.set(style="darkgrid")
sns.set_palette("Set2")
ax.set(ylim=(0,1.01))
ax.set(xlim=(0,1.01))
